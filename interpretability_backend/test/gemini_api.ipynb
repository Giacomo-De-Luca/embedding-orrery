# %%
import os

import pandas as pd
from dotenv import load_dotenv
from google import genai
from google.genai import types
from sklearn.metrics.pairwise import cosine_similarity

load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")


client = genai.Client(api_key=GEMINI_API_KEY)

texts = [
    "What is the meaning of life?",
    "What is the purpose of existence?",
    "How do I bake a cake?",
]

result = client.models.embed_content(
    model="gemini-embedding-001",
    contents=texts,
    config=types.EmbedContentConfig(task_type="SEMANTIC_SIMILARITY"),
)

# Create a 3x3 table to show the similarity matrix
df = pd.DataFrame(
    cosine_similarity([e.values for e in result.embeddings]),
    index=texts,
    columns=texts,
)

print(df)
# Out:
#                                    What is the meaning of life?  \
# What is the meaning of life?                           1.000000
# What is the purpose of existence?                      0.941709
# How do I bake a cake?                                  0.767553
#
#                                    What is the purpose of existence?  \
# What is the meaning of life?                                0.941709
# What is the purpose of existence?                           1.000000
# How do I bake a cake?                                       0.747095
#
#                                    How do I bake a cake?
# What is the meaning of life?                    0.767553
# What is the purpose of existence?               0.747095
# How do I bake a cake?                           1.000000

# %%
# Out:
# AIzaSyBXycQwnvV-yZJHFOKj-hGB9qgWfznz3W4
